# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from typing import Tuple, Optional
# import self-created image obfuscator functions
from src.image_obfuscator import DPImageObfuscator, apply_pixelization, apply_gaussian_blur, apply_dp_pixelization, apply_dp_blur
from src.data_utils import plot_multiple_images, read_image, plot_image

# %% [markdown]
# ## AT&T Face Dataset

# %%
img_folder = os.path.join("..", "att_faces")
img_list = []
subject_list = []
for subject in range(1, 6):
    img = read_image(os.path.join(img_folder, f"s{subject}", "1.pgm"))
    img_list.append(img)
    subject_list.append(f's{subject}')

plot_multiple_images(img_list, titles=subject_list)
# Out:
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)

# %% [markdown]
# ## Pixelized Image

# %%
block_size = 4
img_list = []
subject_list = []
for subject in range(1, 6):
    img = read_image(os.path.join(img_folder, f"s{subject}", "1.pgm"))
    result_image = apply_pixelization(img, block_size)
    img_list.append(result_image)
    subject_list.append(f's{subject}')
    
plot_multiple_images(img_list, titles=subject_list)
# Out:
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)

# %% [markdown]
# ## Gaussian Blur Image

# %%
kernel_size = (11, 11)
sigma = 0
img_list = []
subject_list = []
for subject in range(1, 6):
    img = read_image(os.path.join(img_folder, f"s{subject}", "1.pgm"))
    result_image = apply_gaussian_blur(img, kernel_size, sigma)
    img_list.append(result_image)
    subject_list.append(f's{subject}')
    
plot_multiple_images(img_list, titles=subject_list)
# Out:
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)

# %% [markdown]
# ## DP Pixelized (DP-Pix)

# %%
epsilon = 0.5
m = 16
block_size = 4
img_list = []
subject_list = []
for subject in range(1, 6):
    img = read_image(os.path.join(img_folder, f"s{subject}", "1.pgm"))
    result_image = apply_dp_pixelization(img, epsilon, m, block_size)
    img_list.append(result_image)
    subject_list.append(f's{subject}')
    
plot_multiple_images(img_list, titles=subject_list)
# Out:
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)

# %% [markdown]
# ## DP Gaussian Blur (DP-Blur)

# %%
epsilon = 0.5
m = 16
kernel_size = (11, 11)
sigma = 0
img_list = []
subject_list = []
for subject in range(1, 6):
    img = read_image(os.path.join(img_folder, f"s{subject}", "1.pgm"))
    result_image = apply_dp_blur(img, epsilon, m, kernel_size, sigma)
    img_list.append(result_image)
    subject_list.append(f's{subject}')
    
plot_multiple_images(img_list, titles=subject_list)
# Out:
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
# Input PGM image as grayscale, shape: (112, 92)
